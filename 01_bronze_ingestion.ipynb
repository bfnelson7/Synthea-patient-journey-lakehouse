-- %%
-- =========================================================
-- Bronze: encounters
-- Raw ingestion
-- =========================================================
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.encounters;
COPY INTO health_lakehouse.bronze.encounters
FROM (
    SELECT *,
    _metadata.file_name AS _source_file,
    current_timestamp() AS _ingested_at
    FROM '/Volumes/health_lakehouse/bronze/raw_synthea/encounters.csv'
)
FILEFORMAT =CSV
FORMAT_OPTIONS ('header'='true', 'inferSchema'='true')
COPY_OPTIONS ('mergeSchema'='true');

-- %%
-- confirming encounters table ingestion.
SELECT * FROM health_lakehouse.bronze.encounters LIMIT 5;

-- %%
-- Create empty Delta tables first; COPY INTO requires them to exist
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.patients;
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.conditions;
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.medications;
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.procedures;
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.observations;
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.claims;
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.immunizations;
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.allergies;
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.careplans;
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.providers;
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.organizations;
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.payers;
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.payer_transitions;
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.devices;
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.imaging_studies;
CREATE TABLE IF NOT EXISTS health_lakehouse.bronze.supplies;

-- %%
-- ============================================================
-- BRONZE INGESTION — remaining tables
-- ============================================================

COPY INTO health_lakehouse.bronze.patients
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/patients.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

COPY INTO health_lakehouse.bronze.conditions
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/conditions.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

COPY INTO health_lakehouse.bronze.medications
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/medications.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

COPY INTO health_lakehouse.bronze.procedures
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/procedures.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

COPY INTO health_lakehouse.bronze.observations
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/observations.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

COPY INTO health_lakehouse.bronze.claims
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/claims.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

COPY INTO health_lakehouse.bronze.immunizations
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/immunizations.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

COPY INTO health_lakehouse.bronze.allergies
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/allergies.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

COPY INTO health_lakehouse.bronze.careplans
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/careplans.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

COPY INTO health_lakehouse.bronze.providers
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/providers.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

COPY INTO health_lakehouse.bronze.organizations
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/organizations.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

COPY INTO health_lakehouse.bronze.payers
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/payers.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

COPY INTO health_lakehouse.bronze.payer_transitions
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/payer_transitions.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

COPY INTO health_lakehouse.bronze.devices
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/devices.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

COPY INTO health_lakehouse.bronze.imaging_studies
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/imaging_studies.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

COPY INTO health_lakehouse.bronze.supplies
FROM (SELECT *, _metadata.file_name AS _source_file, current_timestamp() AS _ingested_at
      FROM '/Volumes/health_lakehouse/bronze/raw_synthea/supplies.csv')
FILEFORMAT = CSV FORMAT_OPTIONS ('header'='true','inferSchema'='true') COPY_OPTIONS ('mergeSchema'='true');

-- %%
-- Check entry count for each individual table.
SELECT 'patients' AS tbl, COUNT(*) AS rows FROM health_lakehouse.bronze.patients
UNION ALL SELECT 'encounters', COUNT(*) FROM health_lakehouse.bronze.encounters
UNION ALL SELECT 'conditions', COUNT(*) FROM health_lakehouse.bronze.conditions
UNION ALL SELECT 'medications', COUNT(*) FROM health_lakehouse.bronze.medications
UNION ALL SELECT 'procedures', COUNT(*) FROM health_lakehouse.bronze.procedures
UNION ALL SELECT 'observations', COUNT(*) FROM health_lakehouse.bronze.observations
UNION ALL SELECT 'claims', COUNT(*) FROM health_lakehouse.bronze.claims
UNION ALL SELECT 'immunizations', COUNT(*) FROM health_lakehouse.bronze.immunizations
UNION ALL SELECT 'allergies', COUNT(*) FROM health_lakehouse.bronze.allergies
UNION ALL SELECT 'careplans', COUNT(*) FROM health_lakehouse.bronze.careplans
UNION ALL SELECT 'providers', COUNT(*) FROM health_lakehouse.bronze.providers
UNION ALL SELECT 'organizations', COUNT(*) FROM health_lakehouse.bronze.organizations
UNION ALL SELECT 'payers', COUNT(*) FROM health_lakehouse.bronze.payers
UNION ALL SELECT 'payer_transitions', COUNT(*) FROM health_lakehouse.bronze.payer_transitions
UNION ALL SELECT 'devices', COUNT(*) FROM health_lakehouse.bronze.devices
UNION ALL SELECT 'imaging_studies', COUNT(*) FROM health_lakehouse.bronze.imaging_studies
UNION ALL SELECT 'supplies', COUNT(*) FROM health_lakehouse.bronze.supplies
ORDER BY rows DESC;
